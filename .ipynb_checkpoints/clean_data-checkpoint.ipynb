# %%
import pandas as pd
import json

# %%
# Metadata for 81,741 movies, extracted from the Noverber 4, 2012 dump of Freebase.  Tab-separated; columns:

# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie name
# 4. Movie release date
# 5. Movie box office revenue
# 6. Movie runtime
# 7. Movie languages (Freebase ID:name tuples)
# 8. Movie countries (Freebase ID:name tuples)
# 9. Movie genres (Freebase ID:name tuples)
metadata_cols = ["wiki_id", "freebase_id", "name", "release_date", "revenue", "runtime", "languages", "countries", "genres"]
metadata_df = pd.read_csv('movie.metadata.tsv', sep='\t', names=metadata_cols)
metadata_df = metadata_df[['wiki_id', 'name', 'release_date', 'genres']]
metadata_df['wiki_id'] = metadata_df['wiki_id'].astype(int)

# %%
plot_df = pd.read_csv('plot_summaries.txt', sep='\n', names=['plot'])
plot_df = plot_df['plot'].str.split('\t', expand=True)
plot_df.columns = ['wiki_id', 'plot']
plot_df['wiki_id'] = plot_df['wiki_id'].astype(int)

# %%
plot_df
# Out:
#         wiki_id                                               plot
# 0      23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1      31186339  The nation of Panem consists of a wealthy Capi...
# 2      20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3       2231378  The Lemon Drop Kid , a New York City swindler,...
# 4        595909  Seventh-day Adventist Church pastor Michael Ch...
# ...         ...                                                ...
# 42301  34808485  The story is about Reema , a young Muslim scho...
# 42302   1096473  In 1928 Hollywood, director Leo Andreyev  look...
# 42303  35102018  American Luthier focuses on Randy Parsons’ tra...
# 42304   8628195  Abdur Rehman Khan , a middle-aged dry fruit se...
# 42305   6040782  1940 - Operation Dynamo has just taken place. ...
#
# [42306 rows x 2 columns]

# %%
metadata_df
# Out:
#         wiki_id                                               name  \
# 0        975900                                     Ghosts of Mars
# 1       3196793  Getting Away with Murder: The JonBenét Ramsey ...
# 2      28463795                                        Brun bitter
# 3       9363483                                   White Of The Eye
# 4        261236                                  A Woman in Flames
# ...         ...                                                ...
# 81736  35228177                           Mermaids: The Body Found
# 81737  34980460                                            Knuckle
# 81738   9971909                                  Another Nice Mess
# 81739    913762  The Super Dimension Fortress Macross II: Lover...
# 81740  12476867                                            Spliced
#
#       release_date                                             genres
# 0       2001-08-24  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1       2000-02-16  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2             1988  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3             1987  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4             1983                            {"/m/07s9rl0": "Drama"}
# ...            ...                                                ...
# 81736   2011-03-19                            {"/m/07s9rl0": "Drama"}
# 81737   2011-01-21  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81738   1972-09-22       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81739   1992-05-21  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81740         2002  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 4 columns]

# %%
movie_df = pd.merge(metadata_df, plot_df, on='wiki_id', how='inner')
# Drop na valued roles
movie_df.dropna(inplace=True)
# Format release_date
movie_df['release_date'] = movie_df['release_date'].map(lambda date: date[:4]).astype(int)

movie_df
# Out:
#         wiki_id                                               name  \
# 0        975900                                     Ghosts of Mars
# 1       9363483                                   White Of The Eye
# 2        261236                                  A Woman in Flames
# 3      18998739                          The Sorcerer's Apprentice
# 4       6631279                                        Little city
# ...         ...                                                ...
# 42202  23851782                                    The Ghost Train
# 42203  35228177                           Mermaids: The Body Found
# 42204  34980460                                            Knuckle
# 42205    913762  The Super Dimension Fortress Macross II: Lover...
# 42206  12476867                                            Spliced
#
#        release_date                                             genres  \
# 0              2001  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1              1987  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 2              1983                            {"/m/07s9rl0": "Drama"}
# 3              2002  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 4              1997  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
# ...             ...                                                ...
# 42202          1941  {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...
# 42203          2011                            {"/m/07s9rl0": "Drama"}
# 42204          2011  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 42205          1992  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 42206          2002  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
#                                                     plot
# 0      Set in the second half of the 22nd century, th...
# 1      A series of murders of rich young women throug...
# 2      Eva, an upper class housewife, becomes frustra...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# ...                                                  ...
# 42202  {{plot}} The film opens with a Great Western e...
# 42203  Two former National Oceanic Atmospheric Admini...
# 42204  {{No plot}} This film follows 12 years in the ...
# 42205  The story takes place in the year 2092,The Sup...
# 42206  The movie is about a teenage girl who loves ho...
#
# [39589 rows x 5 columns]

# %%
# Extract moives released in 1990s
movie_df = movie_df[(movie_df['release_date'] >= 1990) & (movie_df['release_date'] <= 1999)]

# %%
movie_df
# Out:
#         wiki_id                                               name  \
# 4       6631279                                        Little city
# 17     26067101                                        Siam Sunset
# 19      9548445                Archie: To Riverdale and Back Again
# 20      2487170                                             Troops
# 27     29198000                                      Chandra Mukhi
# ...         ...                                                ...
# 42184   1191380                                              Wilde
# 42194   7761830                                    Spaced Invaders
# 42198    664006                                      Guilty as Sin
# 42200  15394941                                        Gopi Kishan
# 42205    913762  The Super Dimension Fortress Macross II: Lover...
#
#        release_date                                             genres  \
# 4              1997  {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
# 17             1999  {"/m/06cvj": "Romantic comedy", "/m/02l7c8": "...
# 19             1990                             {"/m/01z4y": "Comedy"}
# 20             1997  {"/m/068twy": "Fan film", "/m/02hmvc": "Short ...
# 27             1993  {"/m/02l7c8": "Romance Film", "/m/07s9rl0": "D...
# ...             ...                                                ...
# 42184          1997  {"/m/0hn10": "LGBT", "/m/017fp": "Biography", ...
# 42194          1990  {"/m/0hj3mt0": "Alien Film", "/m/06n90": "Scie...
# 42198          1993  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 42200          1994  {"/m/07s9rl0": "Drama", "/m/02kdv5l": "Action"...
# 42205          1992  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
#
#                                                     plot
# 4      Adam, a San Francisco-based artist who works a...
# 17     Perry is an English chemist working for a pain...
# 19     Archie Andrews, fifteen years after graduating...
# 20     An example of the film's comedic tone comes in...
# 27     Chandra Mukhi , a princess of a heavenly kingd...
# ...                                                  ...
# 42184  The film opens with Oscar Wilde's 1882 visit t...
# 42194  The space armada from Mars, known as the Imper...
# 42198  Jennifer Haines  is an up-and-coming Chicago a...
# 42200  Kishan  killed a man in his childhood when the...
# 42205  The story takes place in the year 2092,The Sup...
#
# [5827 rows x 5 columns]

# %%
def filter_romance_genre(genre_str):
    genre_dict = json.loads(genre_str)
    genres = genre_dict.values()
    for genre in genres:
        genre_lower = genre.lower()
        if 'romance' in genre_lower or 'romantic' in genre_lower:
            return 'Romance'
    return 'Non-romance'
    
movie_df['genres'] = movie_df['genres'].map(lambda s: filter_romance_genre(s))
# Out:
# <ipython-input-75-6249052a0369>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['genres'] = movie_df['genres'].map(lambda s: filter_romance_genre(s))

# %%
# Extract only romance genre
final_df = movie_df[movie_df['genres'] == 'Romance']

# %%
final_df.shape
# Out:
# (1109, 5)

# %%
final_df
# Out:
#         wiki_id                             name  release_date   genres  \
# 4       6631279                      Little city          1997  Romance
# 17     26067101                      Siam Sunset          1999  Romance
# 27     29198000                    Chandra Mukhi          1993  Romance
# 70      1072373                  Minsaara Kanavu          1997  Romance
# 80      1031231             Black Cat, White Cat          1998  Romance
# ...         ...                              ...           ...      ...
# 42006    699336                      Nine Months          1995  Romance
# 42027  15687214                A Business Affair          1994  Romance
# 42162  11823946  Twelfth Night: Or What You Will          1996  Romance
# 42179  30553937      Confessions of a Sexist Pig          1998  Romance
# 42184   1191380                            Wilde          1997  Romance
#
#                                                     plot
# 4      Adam, a San Francisco-based artist who works a...
# 17     Perry is an English chemist working for a pain...
# 27     Chandra Mukhi , a princess of a heavenly kingd...
# 70     Priya Amal Raj  loses her mother at a very you...
# 80     Matko Destanov, a small-time Roma smuggler and...
# ...                                                  ...
# 42006  Child psychologist Samuel Faulkner's  ideal ro...
# 42027  The film is centred around the life of Kate Sw...
# 42162  Viola  and Sebastian  are young twins and ente...
# 42179  A daytime soap opera star has to deal with his...
# 42184  The film opens with Oscar Wilde's 1882 visit t...
#
# [1109 rows x 5 columns]
